# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv ('/content/drive/My Drive/Dataset/Fish.csv')
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.sample(10)
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 147   Smelt     7.0     10.1     10.6     11.6   1.7284  1.1484
# 71   Parkki   300.0     24.0     26.0     29.0  11.3680  4.2340
# 48    Roach   169.0     22.0     24.0     27.2   7.5344  3.8352
# 136    Pike   540.0     40.1     43.0     45.8   7.7860  5.1296
# 62   Parkki    60.0     14.3     15.5     17.4   6.5772  2.3142
# 122   Perch   820.0     37.1     40.0     42.5  11.1350  6.6300
# 95    Perch   170.0     21.5     23.5     25.0   6.2750  3.7250
# 128    Pike   200.0     30.0     32.3     34.8   5.5680  3.3756
# 123   Perch  1100.0     39.0     42.0     44.6  12.8002  6.8684
# 67   Parkki   170.0     19.0     20.7     23.2   9.3960  3.4104

# %%
data.rename (columns= {'Length1':'abbas'}, inplace=True)
data.sample(10)
# Out:
#     Species  Weight  abbas  Length2  Length3   Height   Width
# 152   Smelt     9.9   11.3     11.8     13.1   2.2139  1.1659
# 67   Parkki   170.0   19.0     20.7     23.2   9.3960  3.4104
# 135    Pike   510.0   40.0     42.5     45.5   6.8250  4.4590
# 23    Bream   680.0   31.8     35.0     40.6  15.4686  6.1306
# 123   Perch  1100.0   39.0     42.0     44.6  12.8002  6.8684
# 26    Bream   720.0   32.0     35.0     40.6  16.3618  6.0900
# 151   Smelt    10.0   11.3     11.8     13.1   2.2139  1.2838
# 146   Smelt     7.5   10.0     10.5     11.6   1.9720  1.1600
# 142    Pike  1600.0   56.0     60.0     64.0   9.6000  6.1440
# 91    Perch   130.0   20.5     22.5     24.0   5.8560  3.6240

# %%
data.head()
# Out:
#   Species  Weight  abbas  Length2  Length3   Height   Width
# 0   Bream   242.0   23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0   24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0   23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0   26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0   26.5     29.0     34.0  12.4440  5.1340

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   abbas    159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
sp = data['Species'].value_counts()
sp
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
sp = pd.DataFrame(sp)
sp
# Out:
#            Species
# Perch           56
# Bream           35
# Roach           20
# Pike            17
# Smelt           14
# Parkki          11
# Whitefish        6

# %%
sp.T
# Out:
#          Perch  Bream  Roach  Pike  Smelt  Parkki  Whitefish
# Species     56     35     20    17     14      11          6

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot (x = sp.index, y=sp['Species'])
plt.xlabel('Species')
plt.ylabel('Counts for Species')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data ['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
data.drop(['abbas'], axis=1, inplace=True)
data
# Out:
#     Species  Weight  Length2  Length3   Height   Width
# 0     Bream   242.0     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...     ...
# 154   Smelt    12.2     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
data = pd.get_dummies (data)
data
# Out:
#      Weight  Length2  Length3  ...  Species_Roach  Species_Smelt  Species_Whitefish
# 0     242.0     25.4     30.0  ...              0              0                  0
# 1     290.0     26.3     31.2  ...              0              0                  0
# 2     340.0     26.5     31.1  ...              0              0                  0
# 3     363.0     29.0     33.5  ...              0              0                  0
# 4     430.0     29.0     34.0  ...              0              0                  0
# ..      ...      ...      ...  ...            ...            ...                ...
# 154    12.2     12.2     13.4  ...              0              1                  0
# 155    13.4     12.4     13.5  ...              0              1                  0
# 156    12.2     13.0     13.8  ...              0              1                  0
# 157    19.7     14.3     15.2  ...              0              1                  0
# ...
